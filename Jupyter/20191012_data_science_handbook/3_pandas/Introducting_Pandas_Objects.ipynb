# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.24.2'

# %%
ind = pd.Index([2, 3, 5, 7, 11])
ind
# Out:
# Int64Index([2, 3, 5, 7, 11], dtype='int64')

# %%
ind[1]
# Out:
# 3

# %%
ind[::2]
# Out:
# Int64Index([2, 5, 11], dtype='int64')

# %%
import inspect

inspect.getmembers(ind)
# Out:
# [('T', Int64Index([2, 3, 5, 7, 11], dtype='int64')),
#  ('__abs__',
#   <bound method Index._add_numeric_methods_unary.<locals>._make_evaluate_unary.<locals>._evaluate_numeric_unary of Int64Index([2, 3, 5, 7, 11], dtype='int64')>),
#  ('__add__',
#   <bound method Int64Index.__add__ of Int64Index([2, 3, 5, 7, 11], dtype='int64')>),
#  ('__and__',
#   <bound method Index.__and__ of Int64Index([2, 3, 5, 7, 11], dtype='int64')>),
#  ('__array__',
#   <bound method Index.__array__ of Int64Index([2, 3, 5, 7, 11], dtype='int64')>),
#  ('__array_priority__', 1000),
#  ('__array_wrap__',
#   <bound method Index.__array_wrap__ of Int64Index([2, 3, 5, 7, 11], dtype='int64')>),
#  ('__bool__',
#   <bound method Index.__nonzero__ of Int64Index([2, 3, 5, 7, 11], dtype='int64')>),
#  ('__bytes__',
#   <bound method StringMixin.__bytes__ of Int64Index([2, 3, 5, 7, 11], dtype='int64')>),
#  ('__class__', pandas.core.indexes.numeric.Int64Index),
#  ('__contains__',
# ...

# %%
import re

attributes = inspect.getmembers(ind)
attrs = [attr for attr in attributes if re.fullmatch(r'(size|shape|ndim|dtype)', attr[0])]
attrs
# Out:
# [('dtype', dtype('int64')), ('ndim', 1), ('shape', (5,)), ('size', 5)]

# %%
indA = pd.Index([1, 3, 5, 7, 9])
indB = pd.Index([2, 3, 5, 7, 11])

# %%
indA & indB
# Out:
# Int64Index([3, 5, 7], dtype='int64')

# %%
indA | indB
# Out:
# Int64Index([1, 2, 3, 5, 7, 9, 11], dtype='int64')

# %%
indA ^ indB
# Out:
# Int64Index([1, 2, 9, 11], dtype='int64')
